# %% [markdown]
# # OP-Map
# A python library with functions and methods for reading .op2 files and element-mapping plotting. It is extensively based on the capabilities of the library **[pyNastran](https://pynastran-git.readthedocs.io/en/latest/#)**.
#
# **Input files:**
# + .op2 file
# + mapping file (in .json format)
# + .bdf file associated to the .op2 file; only if 2D element results need to be transformed to material coordinates
#
# **Capabilities of OP-Map:**
# + read .op2 files created with solver NASTRAN, Altair OPTISTRUCT
# + transform .op2 2D-element results from element coordiante (native format in .op2) to material coordinates
# + plot element mappings of specific structural components as defined in the mapping file.
# + plot mappings of element forces for a specific components and a single load case
# + plot mappings of maximum elemment forces for a specific component for all load cases loaded from the .op2 file
# + change the mapping file initially loaded for a new one
# + list all load cases in the loaded .op2 file
#
#
# FRLM, v0.5

# %%
# Import Model class from OP-Map library
from OP_Map import Model

# %% [markdown]
# ------------------
# ## Plotting M100 HTP torsion box element forces

# %%
# Initialize a variable with the Model class, passing in the .op2 file and element-mapping .json file
M100_model = Model('data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2', 'data/MECEA-HTP-mapping.json')
# Out:
# Created excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %%
# Read into the initialized variable the values of the element forces for cquad4 and tria3 elements
# IMPORTANT: values are passed in as they are in the .op2 file, that is in element coordinates
# For passing in values in material coordinates, use method .r_op2_eforces_matcoord('path_to_bdf_file') instead.
M100_model.r_op2_eforces()
# Out:
# <text style=color:green>INFO:    op2_scalar.py:1556           op2_filename = 'data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2'
# </text>
# Loaded ctria3 and cquad4 element forces from op2 file: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2
# Load cases in the op2 file: 36

# %%
# List the load cases contained in the .op2 file
M100_model.list_lc(excel = True)
# Out:
# [10004, 10021, 10022, 10023, 10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 15004, 15021, 15022, 15023, 15025, 15026, 15027, 15028, 15029, 15030, 15031, 15032, 17004, 17021, 17022, 17023, 17025, 17026, 17027, 17028, 17029, 17030, 17031, 17032]
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %%
# Plot the element-mapping of a specific componente (as defined in the .json file)
M100_model.plot_component_mapping('lhs_upr_skin_panels', excel = True)
# Out:
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %%
# Plotting mappings of element forces for a component, load case and field value
# Field value components acc. to order in .op2/.f06 file
M100_model.plot_eforces(10023, 'lhs_upr_skin_panels', 1, excel=True)
# Out:
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %% [markdown]
# ----------------
# ### Plotting in material coordinates

# %%
# Initialize a new variable with the Model class, passing in the .op2 file and element-mapping .json file
M100_model_mc = Model('data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2', 'data/MECEA-HTP-mapping.json')
# Out:
# Created excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %%
# Read into the initialized variable the values of the element forces for cquad4 and tria3 elements
# in material coordinates
M100_model_mc.r_op2_eforces_matcoord('data/MECEA-OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.bdf')
# Out:
# <text style=color:green>INFO:    op2_scalar.py:1556           op2_filename = 'data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2'
# </text>
# Loaded ctria3 and cquad4 element forces from op2 file: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.op2
# Load cases in the op2 file: 36

# %%
# Plotting mappings of element forces for a component, load case and field value (acc. to order in .op2/.f06 file)
M100_model_mc.plot_eforces(10023, 'lhs_upr_skin_panels', 1, excel=True)
# Out:
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %%
# Plotting mappings of maximum elemment forces and CLC for a specific component for all load cases in the .op2 file
# Field value components acc. to order in .op2/.f06 file
M100_model_mc.plot_max_eforces('lhs_upr_skin_panels', 1, excel=True)
# Out:
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx
# Results saved in excel workbook: data/MECEA-OPTISTRUCT/OPTISTRUCT/M100-HTP-LL1.1_Issue2.0.xlsx

# %% [markdown]
# ------------------
# ## Plotting A320 HTP torsion box element forces

# %%
# Initialize a variable with the Model class, passing in the .op2 file and element-mapping .json file
A320_HTP_model = Model('data/A320-HTP/a320_neo_htp-atl_elev-giv.op2', 'data/A320-HTP/A320-HTP-mapping.json')
# Out:
# Created excel workbook: data/A320-HTP/a320_neo_htp-atl_elev-giv.xlsx

# %%
# Read into the initialized variable the values of the element forces for cquad4 and tria3 elements
# IMPORTANT: values are passed in as they are in the .op2 file, that is in element coordinates
# For passing in values in material coordinates, use method .r_op2_eforces_matcoord('path_to_bdf_file') instead.
A320_HTP_model.r_op2_eforces()
# Out:
# <text style=color:green>INFO:    op2_scalar.py:1556           op2_filename = 'data/A320-HTP/a320_neo_htp-atl_elev-giv.op2'
# </text>
# Loaded ctria3 and cquad4 element forces from op2 file: data/A320-HTP/a320_neo_htp-atl_elev-giv.op2
# Load cases in the op2 file: 397

# %%
# List the load cases contained in the .op2 file
A320_HTP_model.list_lc(excel = True)
# Out:
# [306001, 306002, 306003, 306004, 306005, 306006, 306007, 306008, 306009, 306010, 306011, 306012, 306013, 306014, 306015, 306016, 306017, 306018, 306019, 306020, 306021, 306022, 306023, 306024, 306025, 306026, 306027, 306028, 306029, 306030, 306031, 306032, 306033, 306034, 306035, 306036, 306037, 306038, 306039, 306040, 306041, 306042, 306043, 306044, 306045, 306046, 306047, 306048, 306049, 306050, 306051, 306052, 306053, 306054, 306055, 306056, 306057, 306058, 306059, 306060, 306061, 306062, 306063, 306064, 306065, 306066, 306067, 306068, 306069, 306070, 306071, 306072, 306073, 306074, 306075, 306076, 306077, 306078, 306079, 306080, 306081, 306082, 306083, 306084, 306085, 306086, 306087, 306088, 306089, 306090, 306091, 306092, 306093, 306094, 306095, 306096, 306097, 306098, 306099, 306100, 306101, 306102, 306103, 306104, 306105, 306106, 306107, 306108, 306109, 306110, 316111, 316112, 430101, 430102, 430103, 430104, 430105, 430106, 430107, 430108, 430109, 430110, 430111, 430112, 430113, 430114, 430115, 430116, 430117, 430118, 430119, 430120, 430121, 430122, 430123, 430124, 430125, 430126, 430127, 430128, 430129, 430130, 430131, 430132, 430133, 430134, 430135, 430136, 430137, 430138, 430139, 430140, 430141, 430142, 430143, 430144, 430145, 430146, 430147, 430148, 430149, 430150, 530013, 530014, 530023, 530024, 530033, 530034, 530043, 530044, 530053, 530054, 530063, 530064, 530073, 530074, 530083, 530084, 530093, 530094, 530103, 530104, 530113, 530114, 530123, 530124, 530133, 530134, 530143, 530144, 530153, 530154, 530163, 530164, 530173, 530174, 530183, 530184, 530193, 530194, 530203, 530204, 530213, 530214, 530223, 530224, 530233, 530234, 530243, 530244, 530253, 530254, 550001, 550002, 550003, 550011, 550012, 550013, 550014, 550021, 550022, 550023, 550024, 550031, 550032, 550033, 550034, 550041, 550042, 550043, 550044, 550051, 550052, 550053, 550054, 550061, 550062, 550063, 550064, 550071, 550072, 550073, 550074, 550081, 550082, 550083, 550084, 550091, 550092, 550093, 550094, 550101, 550102, 550103, 550104, 550111, 550112, 550113, 550114, 550121, 550122, 550123, 550124, 600001, 600002, 700011, 700012, 700013, 700014, 700021, 700031, 700041, 700051, 700061, 700071, 700081, 700091, 700101, 750003, 750004, 750005, 750006, 750007, 750008, 750009, 750010, 750011, 750012, 750013, 750014, 750021, 750022, 750023, 750024, 750031, 750032, 750033, 750034, 750041, 750042, 750043, 750044, 750051, 750052, 750053, 750054, 750061, 750062, 750063, 750064, 750071, 750072, 750073, 750074, 750081, 750082, 750083, 750084, 750091, 750092, 750093, 750094, 800011, 800021, 800031, 800041, 800051, 800061, 800062, 800063, 800064, 800071, 800081, 800082, 800083, 800084, 800091, 800101, 850001, 850021, 850022, 850023, 850024, 850031, 850032, 850033, 850034, 850041, 850042, 850043, 850044, 850051, 850052, 850053, 850054, 850061, 850062, 850063, 850064, 850071, 850072, 850073, 850074, 850081, 850082, 850083, 850084, 850091, 850092, 850093, 850094, 850101, 850102, 850103, 850104, 850111, 850112, 850113, 850114, 850121, 850122, 850123, 850124, 850131, 850132, 850133, 850134, 850141, 850142, 850143, 850144, 870001, 870002, 870101, 870102, 870103, 870104]
# Results saved in excel workbook: data/A320-HTP/a320_neo_htp-atl_elev-giv.xlsx

# %%
# Plot the element-mapping of a specific componente (as defined in the .json file)
A320_HTP_model.plot_component_mapping('lwr_skin_panels', excel = True)
# Out:
# Results saved in excel workbook: data/A320-HTP/a320_neo_htp-atl_elev-giv.xlsx

# %%
# Plotting mappings of element forces for a component, load case and field value
# Field value components acc. to order in .op2/.f06 file
A320_HTP_model.plot_eforces(306002, 'lwr_skin_panels', 3, excel = True)
# Out:
# Results saved in excel workbook: data/A320-HTP/a320_neo_htp-atl_elev-giv.xlsx

# %%
# Plotting mappings of maximum elemment forces and CLC for a specific component for all load cases in the .op2 file
# Field value components acc. to order in .op2/.f06 file
A320_HTP_model.plot_max_eforces('lwr_skin_panels', 1, excel = True)
# Out:
# Results saved in excel workbook: data/A320-HTP/a320_neo_htp-atl_elev-giv.xlsx
